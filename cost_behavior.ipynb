# %% [markdown]
# <a href="https://colab.research.google.com/github/qcprof/2026-Fall-305/blob/main/cost_behavior.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cost Behavior Analysis
# ### Cost Accounting I - Riverbend Manufacturing
#
# We have 24 months of production and cost data.
# Our job is to work out how each cost behaves when the number of
# units produced changes.
#
# Cost driver (activity base): Units_Produced

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/cost_behavior_data.csv')
print("R and c:", df.shape)
# display(df.head()), tail, sample, iloc[]
# display(df.info())
# display(df.describe())
# Out:
# R and c: (24, 9)

# %%
df = pd.read_excel('/content/Cost_Behavior_Dataset_Exercise.xlsx')
# display(df.iloc[9])
print("R and c:", df.shape)
# display(df.head()), tail, sample, iloc
# display(df.info())
# display(df.describe())
# Out:
# R and c: (36, 9)
